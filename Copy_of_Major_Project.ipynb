# %% [markdown]
# <a href="https://colab.research.google.com/github/VarshithaGujja/PROJECT/blob/AIML_2024/Copy_of_Major_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("xuedengyue/ednetkt1")
# Out:
# Using Colab cache for faster access to the 'ednetkt1' dataset.

# %%
import os
print("Path:", path)
print(os.listdir(path))\
# Out:
# Path: /kaggle/input/ednetkt1
# ['content']

# %%
# !pip install torch torch-geometric torch-scatter torch-sparse torch-cluster -q
